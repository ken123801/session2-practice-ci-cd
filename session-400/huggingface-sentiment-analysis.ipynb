# %% [markdown]
# # Hugging Face Ready-to-Use Sentiment Analysis
#
#
# ## Objective
#
# We use Hugging Face pretrained pipelines.
#
# We do not train.
#
# We directly use a ready-made sentiment model.
#
# We use China mirror.
#
# We use PyTorch backend.
#
# We test on `imdb_top_500.csv`.
#
# * 1 = Positive
# * 0 = Negative
#
# ---
#
# ## Step 1: Install Libraries

# %%
# !pip install transformers pandas torch -q

# %% [markdown]
# ---
#
# ## Step 2: Set Hugging Face Mirror

# %%
import os

os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

# %% [markdown]
# ---
#
# ## Step 3: Import Libraries

# %%
import pandas as pd

from transformers import pipeline

# %% [markdown]
# ---
#
# ## Step 4: Load Dataset

# %%
df = pd.read_csv("./datasets/imdb_top_500.csv")

# %%
print("Dataset size:", len(df))

print("Columns:", df.columns.tolist())

print("\nFirst review preview:")
print(df["text"].iloc[0][:300])

print("\nFirst label:", df["label"].iloc[0])

print("First rating:", df["rating"].iloc[0])
# Out:
# Dataset size: 500
# Columns: ['text', 'label', 'rating']
#
# First review preview:
# There are lots of extremely good-looking people in this movie. That's probably the best thing about it. Perhaps that even makes it worth watching.<br /><br />"Loaded" tells the story of Tristan Price (Jesse Metcalfe), a young man who's about to make his mark on the world. He's the son of a well-to-d
#
# First label: 0
# First rating: 4

# %% [markdown]
# ---
#
# ## Step 5: Build Hugging Face Pipeline
#
# We use a stable pretrained model.

# %%
classifier = pipeline(
    task="sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    tokenizer="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"
)

# %%
print("Pipeline loaded successfully.")

print("Model name:", classifier.model.name_or_path)
# Out:
# Pipeline loaded successfully.
# Model name: distilbert-base-uncased-finetuned-sst-2-english

# %% [markdown]
# ---
#
# ## Step 6: Check Label Style

# %%
print("Model labels:")
print(classifier.model.config.id2label)
# Out:
# Model labels:
# {0: 'NEGATIVE', 1: 'POSITIVE'}

# %% [markdown]
# ---
#
# ## Step 7: Test One Positive Sentence

# %%
result = classifier("This movie was horrible and I liked it.")

# %%
print("Prediction:")
print(result)
# Out:
# Prediction:
# [{'label': 'POSITIVE', 'score': 0.9982023239135742}]

# %% [markdown]
# ---
#
# ## Step 8: Test One Negative Sentence

# %%
result = classifier("This movie was terrible and boring")

# %%
print("Prediction:")
print(result)
# Out:
# Prediction:
# [{'label': 'NEGATIVE', 'score': 0.9997912049293518}]

# %% [markdown]
# ---
#
# ## Step 9: Predict First 10 IMDB Reviews

# %%
sample_reviews = df["text"].iloc[:10].tolist()

# %%
predictions = classifier(
    sample_reviews,
    truncation=True
)

# %%
print("Total predictions:", len(predictions))

print("\nFirst prediction:")
print(predictions[0])
# Out:
# Total predictions: 10
#
# First prediction:
# {'label': 'NEGATIVE', 'score': 0.9940255880355835}

# %% [markdown]
# ---
#
# ## Step 10: Convert POSITIVE and NEGATIVE into 1 and 0

# %%
def hf_to_label(pred):
    return 1 if pred["label"] == "POSITIVE" else 0

# %%
converted_preds = [
    hf_to_label(pred)
    for pred in predictions
]

# %%
print("Converted predictions:")
print(converted_preds)
# Out:
# Converted predictions:
# [0, 1, 0, 0, 0, 0, 0, 0, 1, 1]

# %% [markdown]
# ---
#
# ## Step 11: Compare with Real Labels

# %%
true_labels = df["label"].iloc[:10].tolist()

# %%
for i in range(10):
    print(f"\nReview {i+1}")
    print("-" * 50)

    print(df["text"].iloc[i][:200])

    print("\nTrue Label:", true_labels[i])

    print("Predicted Label:", converted_preds[i])

    if true_labels[i] == converted_preds[i]:
        print("Result: Correct")
    else:
        print("Result: Incorrect")
# Out:
# Review 1
# --------------------------------------------------
# There are lots of extremely good-looking people in this movie. That's probably the best thing about it. Perhaps that even makes it worth watching.<br /><br />"Loaded" tells the story of Tristan Price
#
# True Label: 0
# Predicted Label: 0
# Result: Correct
#
# Review 2
# --------------------------------------------------
# Home Room deals with a Columbine-like high-school shooting but rather than hashing over the occurrence itself the film portrays the aftermath and what happened to the survivors, their trauma, guilt an
#
# True Label: 1
# Predicted Label: 1
# Result: Correct
#
# Review 3
# --------------------------------------------------
# If I had not read Pat Barker's 'Union Street' before seeing this film, I would have liked it. Unfortuntately this is not the case. It is actually my kind of film, it is well made, and in no way do I w
#
# True Label: 0
# Predicted Label: 0
# Result: Correct
#
# Review 4
# --------------------------------------------------
# "Convicts" is very much a third act sort of film. All the dialogue and character interaction that occurs within it comes out of the long wind-down of a late southern day. And, by extension, the life o
#
# True Label: 1
# Predicted Label: 0
# Result: Incorrect
#
# Review 5
# --------------------------------------------------
# OK, so the musical pieces were poorly written and generally poorly sung (though Walken and Marner, particularly Walken, sounded pretty good). And so they shattered the fourth wall at the end by having
#
# True Label: 1
# Predicted Label: 0
# Result: Incorrect
#
# Review 6
# --------------------------------------------------
# I won't say this movie was bad, but it wasn't good either. I expected something good but I guess Hum Aapke Hain Kaun was much better than this. This was completely old fashioned. At every stage of thi
#
# True Label: 0
# Predicted Label: 0
# Result: Correct
#
# Review 7
# --------------------------------------------------
# Story of a man who has unnatural feelings for a pig. Starts out with a opening scene that is a terrific example of absurd comedy. A formal orchestra audience is turned into an insane, violent mob by t
#
# True Label: 0
# Predicted Label: 0
# Result: Correct
#
# Review 8
# --------------------------------------------------
# "All the world's a stage and its people actors in it"--or something like that. Who the hell said that theatre stopped at the orchestra pit--or even at the theatre door? Why is not the audience partici
#
# True Label: 1
# Predicted Label: 0
# Result: Incorrect
#
# Review 9
# --------------------------------------------------
# While i was the video store i was browsing through the one dollar rentals and came upon this little gem. I don't know what it was about it but i just had a gut instic about it and wow was i ever right
#
# True Label: 1
# Predicted Label: 1
# Result: Correct
#
# Review 10
# --------------------------------------------------
# This is an action Western. James Steart leads an all star cast in the scenic Northwest, which is filmed in great splendor. The scenery and costumes are great. There is action and adventure. Stewart pl
#
# True Label: 0
# Predicted Label: 1
# Result: Incorrect

# %% [markdown]
# ---
#
# ## Step 12: Run on First 50 Reviews

# %%
subset_size = 50

reviews = df["text"].iloc[:subset_size].tolist()

true_labels = df["label"].iloc[:subset_size].tolist()

# %%
predictions = classifier(
    reviews,
    truncation=True,
    batch_size=8
)

# %%
pred_labels = [
    hf_to_label(pred)
    for pred in predictions
]

# %%
print("Finished predicting", len(pred_labels), "reviews.")
# Out:
# Finished predicting 10 reviews.

# %% [markdown]
# ---
#
# ## Step 13: Compute Accuracy

# %%
correct = sum(
    p == y
    for p, y in zip(pred_labels, true_labels)
)

accuracy = correct / len(true_labels)

# %%
print("Accuracy on first", subset_size, "reviews:", accuracy)
# Out:
# Accuracy on first 50 reviews: 0.12

# %% [markdown]
# ---
#
# ## Step 14: View Confidence Scores

# %%
for i in range(5):
    print(f"\nReview {i+1}")

    print("HF Label:", predictions[i]["label"])

    print("Confidence Score:", predictions[i]["score"])
# Out:
# Review 1
# HF Label: NEGATIVE
# Confidence Score: 0.9940255880355835
#
# Review 2
# HF Label: POSITIVE
# Confidence Score: 0.9937600493431091
#
# Review 3
# HF Label: NEGATIVE
# Confidence Score: 0.9467040300369263
#
# Review 4
# HF Label: NEGATIVE
# Confidence Score: 0.963310182094574
#
# Review 5
# HF Label: NEGATIVE
# Confidence Score: 0.9695211052894592

# %% [markdown]
# ---
#
# ## Step 15: Compare Real Reviews More Clearly

# %%
for i in range(5):
    print(f"\nReview {i+1}")
    print("-" * 60)

    print(reviews[i][:300])

    print("\nTrue Label:", true_labels[i])

    print("Predicted Label:", pred_labels[i])

    if true_labels[i] == pred_labels[i]:
        print("Result: Correct")
    else:
        print("Result: Incorrect")
# Out:
# Review 1
# ------------------------------------------------------------
# There are lots of extremely good-looking people in this movie. That's probably the best thing about it. Perhaps that even makes it worth watching.<br /><br />"Loaded" tells the story of Tristan Price (Jesse Metcalfe), a young man who's about to make his mark on the world. He's the son of a well-to-d
#
# True Label: 0
# Predicted Label: 0
# Result: Correct
#
# Review 2
# ------------------------------------------------------------
# Home Room deals with a Columbine-like high-school shooting but rather than hashing over the occurrence itself the film portrays the aftermath and what happened to the survivors, their trauma, guilt and denial.<br /><br />*Spoilers* The shooting itself is treated as a foregone conclusion, with no act
#
# True Label: 1
# Predicted Label: 1
# Result: Correct
#
# Review 3
# ------------------------------------------------------------
# If I had not read Pat Barker's 'Union Street' before seeing this film, I would have liked it. Unfortuntately this is not the case. It is actually my kind of film, it is well made, and in no way do I want to say otherwise, but as an adaptation, it fails from every angle.<br /><br />The harrowing nove
#
# True Label: 0
# Predicted Label: 0
# Result: Correct
#
# Review 4
# ------------------------------------------------------------
# "Convicts" is very much a third act sort of film. All the dialogue and character interaction that occurs within it comes out of the long wind-down of a late southern day. And, by extension, the life of its main character, Soll (Robert Duvall).<br /><br />This is the first collaboration of director P
#
# True Label: 1
# Predicted Label: 0
# Result: Incorrect
#
# Review 5
# ------------------------------------------------------------
# OK, so the musical pieces were poorly written and generally poorly sung (though Walken and Marner, particularly Walken, sounded pretty good). And so they shattered the fourth wall at the end by having the king and his nobles sing about the "battle" with the ogre, and praise the efforts of Puss in Bo
#
# True Label: 1
# Predicted Label: 0
# Result: Incorrect

# %% [markdown]
# ---
#
# ## Step 16: Predict Custom Reviews

# %%
custom_reviews = [
    "This movie was amazing with brilliant acting",
    "I hated this film so much",
    "It was okay, not bad, not great"
]

# %%
custom_preds = classifier(
    custom_reviews,
    truncation=True
)

# %%
for review, pred in zip(custom_reviews, custom_preds):
    print("\nReview:")
    print(review)

    print("HF Label:", pred["label"])

    print("Numeric Label:", hf_to_label(pred))

    print("Score:", pred["score"])
# Out:
# Review:
# This movie was amazing with brilliant acting
# HF Label: POSITIVE
# Numeric Label: 1
# Score: 0.9998835325241089
#
# Review:
# I hated this film so much
# HF Label: NEGATIVE
# Numeric Label: 0
# Score: 0.9996534585952759
#
# Review:
# It was okay, not bad, not great
# HF Label: NEGATIVE
# Numeric Label: 0
# Score: 0.7728215456008911

# %% [markdown]
# ---
#
# ## Step 17: Simple Batch Prediction Function

# %%
def predict_sentiment(text_list):
    preds = classifier(
        text_list,
        truncation=True
    )

    return [
        {
            "text": text,
            "hf_label": pred["label"],
            "numeric_label": hf_to_label(pred),
            "score": pred["score"]
        }
        for text, pred in zip(text_list, preds)
    ]

# %%
sample_results = predict_sentiment([
    "What a wonderful movie",
    "This was a disaster"
])

for item in sample_results:
    print("\nText:", item["text"])

    print("HF Label:", item["hf_label"])

    print("Numeric Label:", item["numeric_label"])

    print("Score:", item["score"])
# Out:
# Text: What a wonderful movie
# HF Label: POSITIVE
# Numeric Label: 1
# Score: 0.9998807907104492
#
# Text: This was a disaster
# HF Label: NEGATIVE
# Numeric Label: 0
# Score: 0.9997826218605042

# %% [markdown]
# ## Your task:
#
# As we can see for the huggingface sentiment analysis task,
#
# with:

# %%
classifier = pipeline(
    task="sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    tokenizer="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"
)
# Out:
# /Users/lunde/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# the model is not strong enough (88% of accuracy for the first 50 reviews, just in per with Bag Of Word + Logistic Regression). the model is kind of small and out-dated.
#
# So, i would like you guys to check out other models.
#
# SEND YOUR FINDINGS HERE IN THE WECHAT GROUP, the model and the accuracy.
#
# Ideally, we should be able to find a good model with, let's say, higher than 95% of accuracy.
